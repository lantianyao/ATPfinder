# %% [markdown]
# # This is a quick tutorial telling you how to use a trained deep forest model.

# %% [markdown]
# ## Import the required packages

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV
from deepforest import CascadeForestClassifier
from sklearn.model_selection import KFold
from sklearn.metrics import matthews_corrcoef, confusion_matrix
from sklearn.metrics import f1_score,precision_score,recall_score,accuracy_score

# %% [markdown]
# ## Load the extracted features and their labels

# %%
df_train = pd.read_csv("data/train_ATP_feature.csv")
df_test = pd.read_csv("data/test_ATP_feature.csv")

# %%
df_train
# Out:
#                    Id                                 Sequence  label  \
# 0        ParaPep_1406                       GNNRPVYIPQPRPPHPRL      0
# 1             AP01299  GLFTLIKGAAKLIGKTVPKKQARLGMNLWLVKLPTNVKT      0
# 2           ADAM_5620                           SCNCVCGFCCSCSP      0
# 3         Positive_40                                RTKKWIVWI      1
# 4        Positive_183    LLGDFFRKSKEKIGKEFKRIVQRIKDFLRNLVPRTES      1
# ..                ...                                      ...    ...
# 857   nonAMP_ID_38763                          DRLLNIQPPPREKMF      0
# 858       Positive_58                         EVEPSDTIENVKAKIQ      1
# 859           AVP0965                          AVASVPRARGKYWWG      0
# 860  nonAMP_ID_129620    KEQLGEEGYREMGHKGGETRKEQLGEEGYREMGHKGG      0
# 861           AVP0740                          GSHTEHTTYAADRFK      0
#
#          AAC|A      AAC|C     AAC|D      AAC|E      AAC|F      AAC|G  \
# 0     0.000000   0.000000  0.000000   0.000000   0.000000   5.555556
# 1     7.692308   0.000000  0.000000   0.000000   2.564103  10.256410
# 2     0.000000  42.857143  0.000000   0.000000   7.142857   7.142857
# 3     0.000000   0.000000  0.000000   0.000000   0.000000   0.000000
# 4     0.000000   0.000000  5.405405   8.108108  10.810811   5.405405
# ..         ...        ...       ...        ...        ...        ...
# 857   0.000000   0.000000  6.666667   6.666667   6.666667   0.000000
# 858   6.250000   0.000000  6.250000  18.750000   0.000000   0.000000
# 859  20.000000   0.000000  0.000000   0.000000   0.000000  13.333333
# 860   0.000000   0.000000  0.000000  24.324324   0.000000  27.027027
# 861  13.333333   0.000000  6.666667   6.666667   6.666667   6.666667
#
#          AAC|H  ...  PAAC|lambda4   PHYC|IEP  PHYC|Net Charge  \
# 0     5.555556  ...      0.236673  11.711365         2.846247
# 1     0.000000  ...      0.149167  11.471863         7.753099
# 2     0.000000  ...      0.139160   5.228699        -0.599259
# 3     0.000000  ...      0.314946  11.166321         2.758094
# 4     0.000000  ...      0.145662  10.605286         5.764731
# ..         ...  ...           ...        ...              ...
# 857   0.000000  ...      0.225993   8.745544         0.763014
# 858   0.000000  ...      0.190854   4.407410        -2.158429
# 859   0.000000  ...      0.245339  11.000549         2.793857
# 860   5.405405  ...      0.181168   5.601257        -2.046280
# 861  13.333333  ...      0.220118   6.921448        -0.063627
#
#      PHYC|Hydrophobic Moment  PHYC|Hydrophobicity  \
# 0                   0.059213             0.094444
# 1                   0.123503            -0.164103
# 2                   0.161821            -0.635714
# 3                   0.422402            -0.366667
# 4                   0.562441             0.621622
# ..                       ...                  ...
# 857                 0.237360             0.413333
# 858                 0.221016             0.700000
# 859                 0.189462            -0.286667
# 860                 0.085521             0.978378
# 861                 0.243351             0.286667
#
#      PHYC|Transmembrane Propensity  PHYC|Aromacity  \
# 0                        -0.962222        0.055556
# 1                        -0.248205        0.051282
# 2                        -0.228571        0.071429
# 3                        -0.150000        0.222222
# 4                        -0.850811        0.108108
# ..                             ...             ...
# 857                      -0.904000        0.066667
# 858                      -1.087500        0.000000
# 859                      -0.222667        0.200000
# 860                      -1.324595        0.054054
# 861                      -0.902000        0.133333
#
#      PHYC|Alpha Helical Propensity  PHYC|Aliphatic Index  PHYC|Boman Index
# 0                         0.819444             59.444444          2.975556
# 1                         1.035128            120.000000          0.246667
# 2                         0.934286             20.714286          0.085714
# 3                         1.007778            118.888889          1.116667
# 4                         1.055676             89.459459          3.000000
# ..                             ...                   ...               ...
# 857                       1.031333             78.000000          2.867333
# 858                       1.075000             91.250000          2.416875
# 859                       0.933333             58.666667          1.258667
# 860                       1.057838             21.081081          3.447568
# 861                       1.021333             13.333333          3.268667
#
# [862 rows x 556 columns]

# %%
train_label = df_train.iloc[:,2].values
test_label = df_test.iloc[:,2].values

# %%
train_AAC = df_train.iloc[:,3:23].values
train_DPC = df_train.iloc[:,23:423].values
train_CKSAAGP = df_train.iloc[:,423:523].values
train_PAAC = df_train.iloc[:,523:547].values
train_PHYC = df_train.iloc[:,547:].values

test_AAC = df_test.iloc[:,3:23].values
test_DPC = df_test.iloc[:,23:423].values
test_CKSAAGP = df_test.iloc[:,423:523].values
test_PAAC = df_test.iloc[:,523:547].values
test_PHYC = df_test.iloc[:,547:].values

train_AAC_DPC_PAAC_CKSAAGP_PHYC = np.concatenate((train_AAC,train_DPC,train_CKSAAGP,train_PAAC,train_PHYC),axis=1)
test_AAC_DPC_PAAC_CKSAAGP_PHYC = np.concatenate((test_AAC,test_DPC,test_CKSAAGP,test_PAAC,test_PHYC),axis=1)

# %% [markdown]
# ## Load the trained model

# %%
model_DF = CascadeForestClassifier()
model_DF.load("model/AAC_DPC_PAAC_CKSAAGP_PHYC")

# %% [markdown]
# ## Predict and output probabilities

# %%
standardScaler = StandardScaler()
standardScaler.fit(train_AAC_DPC_PAAC_CKSAAGP_PHYC)
test_AAC_DPC_PAAC_CKSAAGP_PHYC_std = standardScaler.transform(test_AAC_DPC_PAAC_CKSAAGP_PHYC)
y_prob_DF = model_DF.predict_proba(test_AAC_DPC_PAAC_CKSAAGP_PHYC_std)
y_prob_DF
# Out:
# [2023-03-02 07:57:02.706] Start to evalute the model:
# [2023-03-02 07:57:02.711] Evaluating cascade layer = 0
# [2023-03-02 07:57:02.885] Evaluating cascade layer = 1
# [2023-03-02 07:57:03.048] Evaluating cascade layer = 2
# [2023-03-02 07:57:03.247] Evaluating cascade layer = 3
# array([[0.9045, 0.0955],
#        [0.236 , 0.764 ],
#        [0.9025, 0.0975],
#        [0.045 , 0.955 ],
#        [0.0495, 0.9505],
#        [0.957 , 0.043 ],
#        [0.925 , 0.075 ],
#        [0.7295, 0.2705],
#        [0.971 , 0.029 ],
#        [0.7095, 0.2905],
#        [0.2315, 0.7685],
#        [0.8855, 0.1145],
#        [0.8955, 0.1045],
#        [0.8505, 0.1495],
#        [0.9555, 0.0445],
#        [0.0175, 0.9825],
#        [0.9645, 0.0355],
#        [0.962 , 0.038 ],
#        [0.925 , 0.075 ],
#        [0.174 , 0.826 ],
#        [0.8625, 0.1375],
#        [0.911 , 0.089 ],
#        [0.92  , 0.08  ],
#        [0.053 , 0.947 ],
#        [0.649 , 0.351 ],
#        [0.9465, 0.0535],
#        [0.996 , 0.004 ],
#        [0.9895, 0.0105],
#        [0.939 , 0.061 ],
#        [0.9505, 0.0495],
#        [0.951 , 0.049 ],
#        [0.8685, 0.1315],
#        [0.8405, 0.1595],
#        [0.8885, 0.1115],
#        [0.963 , 0.037 ],
#        [0.906 , 0.094 ],
#        [0.4105, 0.5895],
#        [0.9065, 0.0935],
#        [0.9445, 0.0555],
#        [0.96  , 0.04  ],
#        [0.9045, 0.0955],
#        [0.6935, 0.3065],
#        [0.9265, 0.0735],
#        [0.9925, 0.0075],
#        [0.2855, 0.7145],
#        [0.9355, 0.0645],
#        [0.95  , 0.05  ],
#        [0.765 , 0.235 ],
#        [0.961 , 0.039 ],
#        [0.9535, 0.0465],
#        [0.179 , 0.821 ],
#        [0.9695, 0.0305],
#        [0.3565, 0.6435],
#        [0.9195, 0.0805],
#        [0.933 , 0.067 ],
#        [0.8745, 0.1255],
#        [0.9045, 0.0955],
#        [0.9615, 0.0385],
#        [0.916 , 0.084 ],
#        [0.9555, 0.0445],
#        [0.059 , 0.941 ],
#        [0.9345, 0.0655],
#        [0.945 , 0.055 ],
#        [0.968 , 0.032 ],
#        [0.957 , 0.043 ],
#        [0.9075, 0.0925],
#        [0.926 , 0.074 ],
#        [0.2955, 0.7045],
#        [0.971 , 0.029 ],
#        [0.9305, 0.0695],
#        [0.739 , 0.261 ],
#        [0.644 , 0.356 ],
#        [0.7645, 0.2355],
#        [0.934 , 0.066 ],
#        [0.941 , 0.059 ],
#        [0.9085, 0.0915],
#        [0.4365, 0.5635],
#        [0.8865, 0.1135],
#        [0.9435, 0.0565],
#        [0.882 , 0.118 ],
#        [0.8245, 0.1755],
#        [0.9345, 0.0655],
#        [0.86  , 0.14  ],
#        [0.4305, 0.5695],
#        [0.69  , 0.31  ],
#        [0.9695, 0.0305],
#        [0.534 , 0.466 ],
#        [0.949 , 0.051 ],
#        [0.9185, 0.0815],
#        [0.1185, 0.8815],
#        [0.9755, 0.0245],
#        [0.9015, 0.0985],
#        [0.1985, 0.8015],
#        [0.973 , 0.027 ],
#        [0.9465, 0.0535],
#        [0.9405, 0.0595],
#        [0.9485, 0.0515],
#        [0.9285, 0.0715],
#        [0.852 , 0.148 ],
#        [0.8985, 0.1015],
#        [0.908 , 0.092 ],
#        [0.876 , 0.124 ],
#        [0.9605, 0.0395],
#        [0.3515, 0.6485],
#        [0.891 , 0.109 ],
#        [0.95  , 0.05  ],
#        [0.9665, 0.0335],
#        [0.8495, 0.1505],
#        [0.9015, 0.0985],
#        [0.841 , 0.159 ],
#        [0.962 , 0.038 ],
#        [0.8665, 0.1335],
#        [0.4715, 0.5285],
#        [0.965 , 0.035 ],
#        [0.944 , 0.056 ],
#        [0.865 , 0.135 ],
#        [0.852 , 0.148 ],
#        [0.17  , 0.83  ],
#        [0.939 , 0.061 ],
#        [0.956 , 0.044 ],
#        [0.95  , 0.05  ],
#        [0.942 , 0.058 ],
#        [0.7375, 0.2625],
#        [0.0625, 0.9375],
#        [0.6725, 0.3275],
#        [0.1165, 0.8835],
#        [0.1385, 0.8615],
#        [0.937 , 0.063 ],
#        [0.8745, 0.1255],
#        [0.9305, 0.0695],
#        [0.808 , 0.192 ],
#        [0.9115, 0.0885],
#        [0.806 , 0.194 ],
#        [0.958 , 0.042 ],
#        [0.922 , 0.078 ],
#        [0.9165, 0.0835],
#        [0.533 , 0.467 ],
#        [0.031 , 0.969 ],
#        [0.9445, 0.0555],
#        [0.03  , 0.97  ],
#        [0.949 , 0.051 ],
#        [0.3395, 0.6605],
#        [0.887 , 0.113 ],
#        [0.904 , 0.096 ],
#        [0.941 , 0.059 ],
#        [0.973 , 0.027 ],
#        [0.937 , 0.063 ],
#        [0.845 , 0.155 ],
#        [0.9825, 0.0175],
#        [0.824 , 0.176 ],
#        [0.911 , 0.089 ],
#        [0.8755, 0.1245],
#        [0.746 , 0.254 ],
#        [0.202 , 0.798 ],
#        [0.9195, 0.0805],
#        [0.838 , 0.162 ],
#        [0.878 , 0.122 ],
#        [0.9135, 0.0865],
#        [0.986 , 0.014 ],
#        [0.8525, 0.1475],
#        [0.9835, 0.0165],
#        [0.9205, 0.0795],
#        [0.895 , 0.105 ],
#        [0.96  , 0.04  ],
#        [0.626 , 0.374 ],
#        [0.8105, 0.1895],
#        [0.96  , 0.04  ],
#        [0.9555, 0.0445],
#        [0.9415, 0.0585],
#        [0.9585, 0.0415],
#        [0.759 , 0.241 ],
#        [0.8285, 0.1715],
#        [0.311 , 0.689 ],
#        [0.8345, 0.1655],
#        [0.124 , 0.876 ],
#        [0.9625, 0.0375],
#        [0.78  , 0.22  ],
#        [0.8835, 0.1165],
#        [0.948 , 0.052 ],
#        [0.9675, 0.0325],
#        [0.773 , 0.227 ],
#        [0.91  , 0.09  ],
#        [0.894 , 0.106 ],
#        [0.9495, 0.0505],
#        [0.9595, 0.0405],
#        [0.919 , 0.081 ],
#        [0.9575, 0.0425],
#        [0.1895, 0.8105],
#        [0.965 , 0.035 ],
#        [0.864 , 0.136 ],
#        [0.9255, 0.0745],
#        [0.9805, 0.0195],
#        [0.8715, 0.1285],
#        [0.4095, 0.5905],
#        [0.7845, 0.2155],
#        [0.9   , 0.1   ],
#        [0.898 , 0.102 ],
#        [0.9295, 0.0705],
#        [0.968 , 0.032 ],
#        [0.872 , 0.128 ],
#        [0.651 , 0.349 ],
#        [0.933 , 0.067 ],
#        [0.86  , 0.14  ],
#        [0.9565, 0.0435],
#        [0.9445, 0.0555],
#        [0.8905, 0.1095],
#        [0.9285, 0.0715],
#        [0.402 , 0.598 ],
#        [0.4655, 0.5345],
#        [0.939 , 0.061 ],
#        [0.9105, 0.0895],
#        [0.914 , 0.086 ],
#        [0.8885, 0.1115],
#        [0.9035, 0.0965],
#        [0.9205, 0.0795]])
